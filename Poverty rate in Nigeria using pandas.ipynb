# %% [markdown]
# Using the datasets; List_of_local_governments_in_Nigeria.csv and Nigeria_povertyrate_per_local_gov.csv
#     1. Merge the dataset together to form a single table.
#     2. Remove any redundant columns.
#     3. Calculate how population affects poverty rate of each local government.
#     4. Arrange each local government according to the order of their poverty rate.
#     5. Find the percentage of poverty and sort in ascending order.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
LG = pd.read_csv('C:\\Python class\\Datascience\\Datasets\\Nigeria data\\list_of_local_government_areas_of_nigeria.csv')
pv_rate = pd.read_csv('C:\\Python class\\Datascience\\Datasets\\Nigeria data\\Nigeria povertyrate per local gov.csv')

# %%
LG.head()
# Out:
#   SNo Local Government Area            State  Unnamed: 3
# 0   1                Abadam      Borno State         NaN
# 1   2                 Abaji              FCT         NaN
# 2   3                  Abak  Akwa Ibom State         NaN
# 3   4             Abakaliki     Ebonyi State         NaN
# 4   5             Aba North       Abia State         NaN

# %%
pv_rate.head()
# Out:
#    ID_0  ISO   NAME_0  ID_12 NAME_12  ID_23    NAME_23  2014_Popul  \
# 0   163  NGA  Nigeria      1    Abia      1  Aba North      257689
# 1   163  NGA  Nigeria      1    Abia      2  Aba South      405791
# 2   163  NGA  Nigeria      1    Abia      3   Arochukw      193250
# 3   163  NGA  Nigeria      1    Abia      4      Bende      244399
# 4   163  NGA  Nigeria      1    Abia      5    Ikwuano      139157
#
#    Poverty_Ra  2014_Pover  Unnamed: 10
# 0    0.017378        9661          NaN
# 1    0.094480       16070          NaN
# 2    0.175241       40022          NaN
# 3    0.129469       39410          NaN
# 4    0.111351       12145          NaN

# %%
pv_rate=pv_rate.sort_values(by="NAME_23")
LG = LG.sort_values(by= "Local Government Area")
print(pv_rate)
print(LG)
# Out:
#      ID_0  ISO   NAME_0  ID_12                    NAME_12  ID_23    NAME_23  \
# 0     163  NGA  Nigeria      1                       Abia      1  Aba North
# 1     163  NGA  Nigeria      1                       Abia      2  Aba South
# 141   163  NGA  Nigeria      8                      Borno    142     Abadam
# 275   163  NGA  Nigeria     15  Federal Capital Territory    276      Abaji
# 38    163  NGA  Nigeria      3                  Akwa Ibom     39       Abak
# ..    ...  ...      ...    ...                        ...    ...        ...
# 367   163  NGA  Nigeria     19                     Kaduna    368   ZangonKa
# 368   163  NGA  Nigeria     19                     Kaduna    369      Zaria
# 742   163  NGA  Nigeria     35                     Taraba    743       Zing
# 774   163  NGA  Nigeria     38                    Zamfara    775      Zurmi
# 467   163  NGA  Nigeria     22                      Kebbi    468       Zuru
#
#      2014_Popul  Poverty_Ra  2014_Pover  Unnamed: 10
# ...

# %%
merge=pd.merge(data, pr, left_on='Local Government Area', right_on='NAME_23')
merge.head()
# Out:
#   SNo Local Government Area            State  Unnamed: 3  ID_0  ISO   NAME_0  \
# 0   5             Aba North       Abia State         NaN   163  NGA  Nigeria
# 1   6             Aba South       Abia State         NaN   163  NGA  Nigeria
# 2   1                Abadam      Borno State         NaN   163  NGA  Nigeria
# 3   2                 Abaji              FCT         NaN   163  NGA  Nigeria
# 4   3                  Abak  Akwa Ibom State         NaN   163  NGA  Nigeria
#
#    ID_12                    NAME_12  ID_23    NAME_23  2014_Popul  Poverty_Ra  \
# 0      1                       Abia      1  Aba North      257689    0.017378
# 1      1                       Abia      2  Aba South      405791    0.094480
# 2      8                      Borno    142     Abadam       83113    0.396480
# 3     15  Federal Capital Territory    276      Abaji       60985    0.243414
# 4      3                  Akwa Ibom     39       Abak      153585    0.227546
#
#    2014_Pover  Unnamed: 10
# ...

# %%
merge.isnull().any()
# Out:
# SNo                      False
# Local Government Area    False
# State                    False
# Unnamed: 3                True
# ID_0                     False
# ISO                      False
# NAME_0                   False
# ID_12                    False
# NAME_12                  False
# ID_23                    False
# NAME_23                  False
# 2014_Popul               False
# Poverty_Ra               False
# 2014_Pover               False
# Unnamed: 10               True
# dtype: bool

# %%
merge_new = merge.drop(labels=['NAME_23', 'Unnamed: 3',  'Unnamed: 10', 'NAME_12', 'NAME_0', 'ISO', 'ID_0', 'SNo', 'ID_23', 'ID_12'], axis=1)
merge_new.head()
# Out:
#   Local Government Area            State  2014_Popul  Poverty_Ra  2014_Pover
# 0             Aba North       Abia State      257689    0.017378        9661
# 1             Aba South       Abia State      405791    0.094480       16070
# 2                Abadam      Borno State       83113    0.396480       31093
# 3                 Abaji              FCT       60985    0.243414       14320
# 4                  Abak  Akwa Ibom State      153585    0.227546       33179

# %%
# merge['SNo'] = np.arange(1, merge['SNo'].count()+1)
# merge = merge.reindex(merge['SNo'])
# merge

# %%
# new_data= merge.set_index('Local Government Area', inplace=True)
# poverty= merge['Poverty_Ra']/1
# poverty.sort_values(ascending=True, inplace=True)
# poverty
merge_new.sort_values(by='Poverty_Ra', ascending=True)
# Out:
#     Local Government Area         State  2014_Popul  Poverty_Ra  2014_Pover
# 158                 Fagge    Kano State      859163    0.004566        4250
# 524          Sokoto North  Sokoto State      246991    0.009919        1496
# 567                 Uvwie   Delta State      289312    0.016641        4621
# 0               Aba North    Abia State      257689    0.017378        9661
# 76                   Bida   Niger State      240860    0.018769        5264
# ..                    ...           ...         ...         ...         ...
# 438              Ohaozara  Ebonyi State      167245    0.842780      140108
# 156            Ezza North  Ebonyi State      158054    0.844616      131690
# 439               Ohaukwu  Ebonyi State      253736    0.862090      220785
# 157            Ezza South  Ebonyi State      168892    0.903956      151608
# 245                  Ikwo  Ebonyi State      215257    0.914384      197512
#
# [595 rows x 5 columns]

# %%
pover = merge['2014_Pover']
total=pover.sum()
percentage = pover/total*100
merge_new['percent'] = percentage
# percentage.sort_values(ascending=True, inplace=True)
# percentage
merge_new.sort_values(by='percent', ascending=True)
# Out:
#     Local Government Area          State  2014_Popul  Poverty_Ra  2014_Pover  \
# 182                 Gombe    Gombe State        1998    0.064751          86
# 459         Onitsha South  Anambra State       12742    0.051663         583
# 525          Sokoto South   Sokoto State       62355    0.030574        1052
# 270                Isokan     Osun State       10070    0.114867        1068
# 524          Sokoto North   Sokoto State      246991    0.009919        1496
# ..                    ...            ...         ...         ...         ...
# 119                 Demsa  Adamawa State      451803    0.664365      226943
# 373                  Maru  Zamfara State      449533    0.502184      227452
# 544                  Toro   Bauchi State      452403    0.518579      234115
# 404                 Ningi   Bauchi State      514395    0.465733      237526
# 194                 Gusau  Zamfara State      632738    0.507022      238909
#
#       percent
# 182  0.000224
# ...

# %%
# plt.plot(merge_new, merge_new);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
# plt.style.use('seaborn-whitegrid')
# fig = plt.figure()
# new_merge = plt.axes()
# plt.plot(merge_new, merge_new)
# plt.show()
# x = np.linspace(0, 2, 100)
# plt.plot(x, x, label='linear')
# plt.plot(x, x**2, label='quadratic')
# plt.plot(x, x**3, label='cubic')
# plt.xlabel('x Axes')
# plt.ylabel('y Axes')
# plt.title("Simple Plot")
# plt.legend();
